# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv("E:\\Msc Systems Biology\\MSB5000_Master_Thesis\\Practical work\\Data\\Data_Full_Datasets\\GSE66351\\EWAS\\Results_small_dataset.csv", index_col=0)

# %%
ids = test.sort_values(by = ["corr_pval"]).head(10).index.values
test.sort_values(by = ["corr_pval"]).head(10)
# Out:
#             Diagnosis_Beta  Diagnosis_SE   Diagnosis_P  corr_pval
# cg11758688        0.253623      0.037405  2.003004e-10   0.000090
# cg23289794        0.023096      0.003472  4.014507e-10   0.000090
# cg11992265       -0.061213      0.010078  8.251315e-09   0.001240
# cg26516741       -0.011325      0.002061  1.445167e-07   0.016288
# cg04083966       -0.099800      0.018331  1.842124e-07   0.016610
# cg09324326       -0.065236      0.012091  2.323074e-07   0.017455
# cg00270291        0.026727      0.004990  2.796874e-07   0.018013
# cg18626282       -0.005597      0.001065  4.493676e-07   0.025324
# cg13024624       -0.027621      0.005286  5.160134e-07   0.025849
# cg14091713       -0.035844      0.007002  8.410740e-07   0.031675

# %%
test1 = pd.read_csv("E:\\Msc Systems Biology\\MSB5000_Master_Thesis\\Practical work\\Data\\GSE66351_Fed\\_mild_Results_EWAS1.csv", index_col=0, header=[0,1])

# %%
test1.loc[ids, [("Coefficient", "Diagnosis"), ("P-value", "Diagnosis"), ("Corrected P-value", "Diagnosis")]]
# Out:
#            Coefficient   P-value Corrected P-value
#              Diagnosis Diagnosis         Diagnosis
# cg11758688   -0.236453  0.999883          0.999883
# cg23289794   -0.018509  0.630073          0.635998
# cg11992265    0.113489  0.025041          0.598553
# cg26516741    0.008711  0.437852          0.598553
# cg04083966    0.102898  0.036863          0.598553
# cg09324326    0.077768  0.085321          0.598553
# cg00270291   -0.026933  0.685300          0.687450
# cg18626282    0.005999  0.457102          0.598553
# cg13024624    0.029536  0.298416          0.598553
# cg14091713    0.035548  0.262444          0.598553

# %%
test1.loc[:,[("Coefficient", "Diagnosis"), ("P-value", "Diagnosis"), ("Corrected P-value", "Diagnosis")]].sort_values(by = [("Corrected P-value", "Diagnosis")])
# Out:
#            Coefficient   P-value Corrected P-value
#              Diagnosis Diagnosis         Diagnosis
# cg00000029   -0.005312  0.537997          0.598553
# cg17458347   -0.002251  0.516123          0.598553
# cg17458101    0.000566  0.495946          0.598553
# cg17458053    0.002662  0.480933          0.598553
# cg17457986   -0.004130  0.529563          0.598553
# ...                ...       ...               ...
# cg27518014   -0.141060  0.991532          0.991541
# cg14893161   -0.144208  0.992564          0.992571
# cg06618134   -0.155745  0.995425          0.995430
# cg22543924   -0.159261  0.996065          0.996068
# cg11758688   -0.236453  0.999883          0.999883
#
# [450837 rows x 3 columns]
